# %% [markdown]
# <a href="https://colab.research.google.com/github/SaiEshwar-Pennada/fraud_credit_card_prediction_ml/blob/main/fraud_credit_card_prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
credit_card_data = pd.read_csv('/content/creditcard.csv')

# %%
credit_card_data.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0     0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1     0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2     1 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3     1 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4     2 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
credit_card_data.tail()
# Out:
#         Time        V1        V2        V3        V4        V5        V6  \
# 23853  32953  1.296815 -0.518508  0.348800  0.129750 -0.845934 -0.283287
# 23854  32954  1.295646 -0.699613 -1.129649 -2.505043  1.428275  3.010605
# 23855  32954 -1.691394 -1.452403  1.671861 -1.769590  1.636843 -0.943701
# 23856  32954  1.112786  0.062772  1.481419  2.922471 -0.905121  0.366357
# 23857  32954 -0.264220  1.107046  0.985544  0.346904  1.121035  0.069275
#
#              V7        V8        V9  ...       V21       V22       V23  \
# 23853 -0.463165 -0.007344 -0.530097  ... -0.498652 -0.791893  0.058456
# 23854 -0.892932  0.798386  1.309837  ...  0.071540  0.120545 -0.144172
# 23855  0.193116 -0.712756 -0.987725  ...  0.047745  0.539167 -0.698010
# 23856 -0.670663  0.256586  0.599399  ...  0.010125  0.346740 -0.117334
# 23857  1.307409 -0.681733  0.346650  ... -0.159083       NaN       NaN
#
#             V24       V25       V26       V27       V28  Amount  Class
# ...

# %%
credit_card_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23858 entries, 0 to 23857
# Data columns (total 31 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Time    23858 non-null  int64
#  1   V1      23858 non-null  float64
#  2   V2      23858 non-null  float64
#  3   V3      23858 non-null  float64
#  4   V4      23858 non-null  float64
#  5   V5      23858 non-null  float64
#  6   V6      23858 non-null  float64
#  7   V7      23858 non-null  float64
#  8   V8      23858 non-null  float64
#  9   V9      23858 non-null  float64
#  10  V10     23858 non-null  float64
#  11  V11     23858 non-null  float64
#  12  V12     23858 non-null  float64
#  13  V13     23858 non-null  float64
#  14  V14     23858 non-null  float64
#  15  V15     23858 non-null  float64
#  16  V16     23858 non-null  float64
#  17  V17     23858 non-null  float64
#  18  V18     23858 non-null  float64
#  19  V19     23858 non-null  float64
# ...

# %%
credit_card_data.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       1
# V23       1
# V24       1
# V25       1
# V26       1
# V27       1
# V28       1
# Amount    1
# Class     1
# dtype: int64

# %%
credit_card_data['Class'].value_counts()
# Out:
# 0.0    23769
# 1.0       88
# Name: Class, dtype: int64

# %% [markdown]
# **This Dataset is highly unblanced**

# %% [markdown]
# 0 --> Normal Transaction
#
# 1 --> fraudulent transaction

# %%
legit = credit_card_data[credit_card_data.Class == 0]
fraud = credit_card_data[credit_card_data.Class == 1]

# %%
print(legit.shape)
print(fraud.shape)
# Out:
# (23769, 31)
# (88, 31)

# %%
legit.Amount.describe()
# Out:
# count    23769.000000
# mean        73.880199
# std        212.541174
# min          0.000000
# 25%          6.000000
# 50%         18.110000
# 75%         65.850000
# max       7879.420000
# Name: Amount, dtype: float64

# %%
fraud.Amount.describe()

# %%
credit_card_data.groupby('Class').mean()

# %% [markdown]
# **Under-Sampling**

# %% [markdown]
# Build a sample dataset containing similar distribution of normal transactions and Fraudulent Transactions

# %% [markdown]
# number of fraudulent transactions -> 88

# %%
legit_sample = legit.sample(n=88)

# %%
new_dataset = pd.concat([legit_sample, fraud], axis=0)

# %%
new_dataset.head()
# Out:
#         Time        V1        V2        V3        V4        V5        V6  \
# 12881  22637  0.879295  0.001973 -0.094510  1.264449  0.544229  0.705941
# 10602  17714  1.165141  0.320241  0.748290  0.699524 -0.200575 -0.252235
# 2018    1559 -1.708542 -0.422822  1.427453  3.068665  2.093445 -0.833451
# 9317   13496  1.033365 -0.014854  1.072888  1.591331 -0.216666  1.131354
# 23855  32954 -1.691394 -1.452403  1.671861 -1.769590  1.636843 -0.943701
#
#              V7        V8        V9  ...       V21       V22       V23  \
# 12881  0.168938  0.193764  1.159581  ...  0.037570  0.273465 -0.036151
# 10602 -0.163383 -0.051001  0.952167  ... -0.308114 -0.611355  0.183370
# 2018   0.073657  0.083761 -2.183455  ...  0.270275  0.115894  0.087083
# 9317  -0.647461  0.370989  1.869981  ... -0.153431  0.183275 -0.042846
# 23855  0.193116 -0.712756 -0.987725  ...  0.047745  0.539167 -0.698010
#
#             V24       V25       V26       V27       V28  Amount  Class
# ...

# %%
new_dataset.tail()
# Out:
#         Time        V1        V2        V3        V4        V5        V6  \
# 18773  29753  0.269614  3.549755 -5.810353  5.809370  1.538808 -2.269219
# 18809  29785  0.923764  0.344048 -2.880004  1.721680 -3.019565 -0.639736
# 20198  30852 -2.830984  0.885657  1.199930  2.861292  0.321669  0.289966
# 23308  32686  0.287953  1.728735 -1.652173  3.813544 -1.090927 -0.984745
# 23422  32745 -2.179135  0.020218 -2.182733  2.572046 -3.663733  0.081568
#
#              V7        V8        V9  ...       V21       V22       V23  \
# 18773 -0.824203  0.351070 -3.759059  ...  0.371121 -0.322290 -0.549856
# 18809 -3.801325  1.299096  0.864065  ...  0.899931  1.481271  0.725266
# 20198  1.767760 -2.451050  0.069736  ...  0.546589  0.334971  0.172106
# 23308 -2.202318  0.555088 -2.033892  ...  0.262202 -0.633528  0.092891
# 23422  0.268049  0.660437 -2.374027  ...  1.026421  0.299614  1.656800
#
#             V24       V25       V26       V27       V28  Amount  Class
# ...

# %%
new_dataset['Class'].value_counts()
# Out:
# 0.0    88
# 1.0    88
# Name: Class, dtype: int64

# %%
new_dataset.groupby('Class').mean()
# Out:
#                Time        V1        V2         V3        V4        V5  \
# Class
# 0.0    17120.715909 -0.052180  0.266729   0.737857  0.178650 -0.098898
# 1.0    17935.875000 -8.613716  6.376169 -12.221731  6.231847 -6.027247
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0.0    0.221557 -0.058617 -0.010756  0.560790  ...  0.037077 -0.042963
# 1.0   -2.487080 -8.308784  4.351326 -2.987199  ...  0.714069  0.539387
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0.0   -0.128164 -0.062980  0.044697  0.160886 -0.078906  0.016202 -0.000580
# 1.0   -0.381823 -0.350615 -0.252970  0.346695  0.179760  0.856336  0.100578
#
#            Amount
# Class
# 0.0     66.340455
# 1.0    100.010000
#
# [2 rows x 30 columns]

# %%
X = new_dataset.drop(columns='Class', axis=1)
Y = new_dataset['Class']

# %%
print(X)
# Out:
#         Time        V1        V2        V3        V4        V5        V6  \
# 12881  22637  0.879295  0.001973 -0.094510  1.264449  0.544229  0.705941
# 10602  17714  1.165141  0.320241  0.748290  0.699524 -0.200575 -0.252235
# 2018    1559 -1.708542 -0.422822  1.427453  3.068665  2.093445 -0.833451
# 9317   13496  1.033365 -0.014854  1.072888  1.591331 -0.216666  1.131354
# 23855  32954 -1.691394 -1.452403  1.671861 -1.769590  1.636843 -0.943701
# ...      ...       ...       ...       ...       ...       ...       ...
# 18773  29753  0.269614  3.549755 -5.810353  5.809370  1.538808 -2.269219
# 18809  29785  0.923764  0.344048 -2.880004  1.721680 -3.019565 -0.639736
# 20198  30852 -2.830984  0.885657  1.199930  2.861292  0.321669  0.289966
# 23308  32686  0.287953  1.728735 -1.652173  3.813544 -1.090927 -0.984745
# 23422  32745 -2.179135  0.020218 -2.182733  2.572046 -3.663733  0.081568
#
#              V7        V8        V9  ...       V20       V21       V22  \
# ...

# %%
print(Y)
# Out:
# 12881    0.0
# 10602    0.0
# 2018     0.0
# 9317     0.0
# 23855    0.0
#         ...
# 18773    1.0
# 18809    1.0
# 20198    1.0
# 23308    1.0
# 23422    1.0
# Name: Class, Length: 176, dtype: float64

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, stratify=Y, random_state=2)

# %%
print(X.shape, X_train.shape, X_test.shape)
# Out:
# (176, 30) (140, 30) (36, 30)

# %% [markdown]
# model training
#
# logistic regression

# %%
model = LogisticRegression()

# %%
model.fit(X_train, Y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %% [markdown]
# model accuracy

# %%
X_train_prediction = model.predict(X_train)
training_data_accuracy = accuracy_score(X_train_prediction, Y_train)

# %%
print('Accuracy on Training data : ', training_data_accuracy)
# Out:
# Accuracy on Training data :  1.0

# %%
X_test_prediction = model.predict(X_test)
test_data_accuracy = accuracy_score(X_test_prediction, Y_test)

# %%
print('Accuracy score on Test Data : ', test_data_accuracy)
# Out:
# Accuracy score on Test Data :  0.9722222222222222
